# %% [markdown]
# # Rishik Reddy Bandi
# # 220968300
# # Week3 MultipleRegression-Diabetes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(df)
# Out:
# C:\Users\rrban\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
X=df.iloc[:,2:-1]
X
# Out:
#      BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  \
# 0               72             35        0  33.6                     0.627
# 1               66             29        0  26.6                     0.351
# 2               64              0        0  23.3                     0.672
# 3               66             23       94  28.1                     0.167
# 4               40             35      168  43.1                     2.288
# ..             ...            ...      ...   ...                       ...
# 763             76             48      180  32.9                     0.171
# 764             70             27        0  36.8                     0.340
# 765             72             23      112  26.2                     0.245
# 766             60              0        0  30.1                     0.349
# 767             70             31        0  30.4                     0.315
#
#      Age
# 0     50
# 1     31
# 2     32
# 3     21
# 4     33
# ...

# %%
y=df.iloc[:,1]
y
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 0.12890078, -0.44324411,  0.10815423,  0.81092772, 10.11686323,
#         0.62032085])

# %%
model.intercept_
# Out:
# 61.08762125514701

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([133.08170463, 100.04552156, 108.93904738, 121.0994497 ,
#        130.07601442, 144.70145499, 100.97391722, 125.22001204,
#        122.89524006, 140.99647801, 106.68290908, 126.20477283,
#        135.8116226 , 133.9016991 , 103.19691057, 121.96995136,
#        106.42136347, 108.18124534, 108.59429404, 125.79546421,
#        125.30427848, 114.13917123, 105.82849001, 109.65240982,
#        127.80560153, 115.1008067 ,  95.96000699, 104.9719314 ,
#        121.64424037, 126.5262695 , 123.20590837, 149.18486544,
#        135.71920716, 114.37826026, 149.6191823 , 131.80463056,
#         98.64578989, 117.71082808, 126.17647738, 114.97959378,
#        107.12058797, 135.11021147, 131.16728935, 123.94595623,
#        108.35490911, 133.02882911, 150.80975561, 106.80529928,
#        133.98314634, 171.03113409,  94.26874998, 140.45425466,
#        160.8567927 , 113.29720661, 117.29913909, 103.6251534 ,
#        135.45072645,  76.4950142 , 121.13971037, 122.81572476,
# ...

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 22.830874026720952
# Mean Squared Error: 822.1733198945025
# Root Mean Squared Error: 28.673564827110397

# %%
plt.scatter(x_test['BloodPressure'], y_test, color='black', label='Actual')
plt.scatter(x_test['BloodPressure'], y_pred, color='blue', label='Predicted')
plt.xlabel('BloodPressure')
plt.ylabel('Glucose')
plt.legend()
plt.show()

# %%
plt.scatter(x_test['SkinThickness'], y_test, color='black', label='Actual')
plt.scatter(x_test['SkinThickness'], y_pred, color='blue', label='Predicted')
plt.xlabel('SkinThickness')
plt.ylabel('Glucose')
plt.legend()
plt.show()

# %%
plt.scatter(x_test['Insulin'], y_test, color='black', label='Actual')
plt.scatter(x_test['Insulin'], y_pred, color='blue', label='Predicted')
plt.xlabel('Insulin')
plt.ylabel('Glucose')
plt.legend()
plt.show()

# %%
plt.scatter(x_test['BMI'], y_test, color='black', label='Actual')
plt.scatter(x_test['BMI'], y_pred, color='blue', label='Predicted')
plt.xlabel('BMI')
plt.ylabel('Glucose')
plt.legend()
plt.show()

# %%
plt.scatter(x_test['DiabetesPedigreeFunction'], y_test, color='black', label='Actual')
plt.scatter(x_test['DiabetesPedigreeFunction'], y_pred, color='blue', label='Predicted')
plt.xlabel('DiabetesPedigreeFunction')
plt.ylabel('Glucose')
plt.legend()
plt.show()

# %%
plt.scatter(x_test['Age'], y_test, color='black', label='Actual')
plt.scatter(x_test['Age'], y_pred, color='blue', label='Predicted')
plt.xlabel('Age')
plt.ylabel('Glucose')
plt.legend()
plt.show()

# %%
sns.pairplot(df,kind='reg')
# Out:
# C:\Users\rrban\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 22.830874026720952
# Mean Squared Error: 822.1733198945025
# Root Mean Squared Error: 28.673564827110397
